# %% [markdown]
# <a href="https://colab.research.google.com/github/achmadfauzannur/PCVK_Genap_2021/blob/main/week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
from skimage import io
from skimage import transform
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.morphology import (erosion, dilation, closing, opening,
                                   area_closing, area_opening)
from skimage.color import rgb2gray

# %%
img = cv.imread('/content/drive/MyDrive/j.png')

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)


plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a92622d0>,
#  <matplotlib.image.AxesImage at 0x7f80a9240b90>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a91c2050>,
#  <matplotlib.image.AxesImage at 0x7f80a8d0b590>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
        
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a8c19790>,
#  <matplotlib.image.AxesImage at 0x7f80a8be3090>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
        
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a8b6e990>,
#  <matplotlib.image.AxesImage at 0x7f80a8b42050>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
        
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a8abea50>,
#  <matplotlib.image.AxesImage at 0x7f80a8a12290>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
        
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a8993b90>,
#  <matplotlib.image.AxesImage at 0x7f80a8963390>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a88ead90>,
#  <matplotlib.image.AxesImage at 0x7f80a88b8550>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 5x5'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a881f7d0>,
#  <matplotlib.image.AxesImage at 0x7f80a8803710>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 3x3'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (3, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 3x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a88cf590>,
#  <matplotlib.image.AxesImage at 0x7f80a874d110>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 3x5'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a86d8610>,
#  <matplotlib.image.AxesImage at 0x7f80a8622a50>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 5x7'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (1, 3))
cross4 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross4), plt.title('Citra Hasil Vertical 3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a8ba8390>,
#  <matplotlib.image.AxesImage at 0x7f80a8bc2990>,
#  Text(0.5, 1.0, 'Citra Hasil Vertical 3'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (1, 5))
cross4 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross4), plt.title('Citra Hasil Vertical 5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f80a8602ed0>,
#  <matplotlib.image.AxesImage at 0x7f80a8579450>,
#  Text(0.5, 1.0, 'Citra Hasil Vertical 5'))
